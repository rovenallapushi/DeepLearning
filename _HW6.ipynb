# %% [markdown]
# # **Deep Learning Homework 6: *Variational Autoencoders***
# ### MSc Computer Science, Data Science, Cybersecurity Computer Engeneering @UniPD
# ### 2nd semester - 6 ECTS
# ### Prof. Alessandro Sperduti, Prof. Nicolò Navarin & Dr. Luca Pasa
# ---
#
# In this homework, we will explore how to develop a Variational Autoencoder (VAE). We will define a Variational Autoencoder starting from basic PyTorch components. Then, we will define a training loop which includes the two losses used to train VAEs, namely the reconstruction loss and the KL-divergence loss.
# Using this training loop, we will fit the model on the MNIST dataset choosing  appropriate hyperparameters. Finally, we will and explore and analyze the latent encodings learned by the model thanks to some visualization techniques.
#
# **NOTE**: in order to run this notebook without problems, please connect to a *GPU runtime*. You can do so by clicking on the RAM / Disk icon in the upper right part of the notebook, then on *Change runtime type* at the bottom of the page, and then select the GPU hardware accelerator.

# %% [markdown]
# #Requirements

# %%
# !pip3 install datasets skorch pandas~=1.5 torch~=1.13 torchinfo torchdata~=0.5 torchtext~=0.14 torchvision~=0.14 torchaudio~=0.13
# Out:
# Requirement already satisfied: datasets in c:\users\roven\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: skorch in c:\users\roven\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: pandas~=1.5 in c:\users\roven\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: torch~=1.13 in c:\users\roven\anaconda3\lib\site-packages (1.13.1)
# Requirement already satisfied: torchinfo in c:\users\roven\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: torchdata~=0.5 in c:\users\roven\anaconda3\lib\site-packages (0.5.1)
# Requirement already satisfied: torchtext~=0.14 in c:\users\roven\anaconda3\lib\site-packages (0.14.1)
# Requirement already satisfied: torchvision~=0.14 in c:\users\roven\anaconda3\lib\site-packages (0.14.1)
# Requirement already satisfied: torchaudio~=0.13 in c:\users\roven\anaconda3\lib\site-packages (0.13.1)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (2023.3.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (6.0)
# Requirement already satisfied: aiohttp in c:\users\roven\anaconda3\lib\site-packages (from datasets) (3.8.4)
# Requirement already satisfied: responses<0.19 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (0.18.0)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (11.0.0)
# Requirement already satisfied: packaging in c:\users\roven\anaconda3\lib\site-packages (from datasets) (21.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (0.3.6)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (4.62.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (2.26.0)
# Requirement already satisfied: multiprocess in c:\users\roven\anaconda3\lib\site-packages (from datasets) (0.70.14)
# Requirement already satisfied: xxhash in c:\users\roven\anaconda3\lib\site-packages (from datasets) (3.2.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (0.13.4)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\roven\anaconda3\lib\site-packages (from skorch) (0.9.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\roven\anaconda3\lib\site-packages (from skorch) (1.7.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\roven\anaconda3\lib\site-packages (from skorch) (0.24.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\roven\anaconda3\lib\site-packages (from pandas~=1.5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\roven\anaconda3\lib\site-packages (from pandas~=1.5) (2021.3)
# Requirement already satisfied: typing_extensions in c:\users\roven\anaconda3\lib\site-packages (from torch~=1.13) (3.10.0.2)
# Requirement already satisfied: urllib3>=1.25 in c:\users\roven\anaconda3\lib\site-packages (from torchdata~=0.5) (1.26.7)
# Requirement already satisfied: portalocker>=2.0.0 in c:\users\roven\anaconda3\lib\site-packages (from torchdata~=0.5) (2.7.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\roven\anaconda3\lib\site-packages (from torchvision~=0.14) (8.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\roven\anaconda3\lib\site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\roven\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\roven\anaconda3\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\roven\anaconda3\lib\site-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\roven\anaconda3\lib\site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\roven\anaconda3\lib\site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\roven\anaconda3\lib\site-packages (from aiohttp->datasets) (21.2.0)
# Requirement already satisfied: filelock in c:\users\roven\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.3.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\roven\anaconda3\lib\site-packages (from packaging->datasets) (3.0.4)
# Requirement already satisfied: pywin32>=226 in c:\users\roven\anaconda3\lib\site-packages (from portalocker>=2.0.0->torchdata~=0.5) (228)
# Requirement already satisfied: six>=1.5 in c:\users\roven\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas~=1.5) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\roven\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\roven\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: joblib>=0.11 in c:\users\roven\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->skorch) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\roven\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->skorch) (2.2.0)
# Requirement already satisfied: colorama in c:\users\roven\anaconda3\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.4)

# %% [markdown]
# #Imports

# %%
import torch
from torch import nn
import torch.nn.functional as F
import torchvision.datasets as datasets
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torchinfo import summary
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from timeit import default_timer as timer
import warnings
warnings.filterwarnings("ignore")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# #Data Loading and Preprocessing
#
# We load the MNIST dataset. The dataset contains 60,000 training grayscale images and 10,000 testing image of handwritten digits. We chose to use a 128-dimensional batch in order to make the training process reasonably fast -- you should thus leave this value unchanged.

# %%
Trns = transforms.ToTensor()
def preprocess(img):
  img = Trns(img)
  H, W = img.shape[1:]
  img = img.reshape((H*W, ))
  return img

MNIST = datasets.MNIST(root='./data', train=True, download=True, transform=preprocess)

# %%
batch_size = 128
dataloader = DataLoader(MNIST, batch_size=batch_size, shuffle=True)

# %% [markdown]
# Let us see one of the digits:

# %%
data_iter = iter(dataloader)
images, labels = next(data_iter)

plt.imshow(images[0].reshape(28,28), cmap='gray')
plt.title(f"Label: {labels[0]+1}")
plt.show()

# %% [markdown]
# #[TO COMPLETE] VAE Architecture
#
# ###Exercise 6.1: Variational Autoencoder: reparameterization trick
# To implement a VAE we have to define two main parts: the _Encoder_ and the _Decoder_.
# Let's start by the Encoder, that computes an encoding of the input from which it computes the mean and the average of the sample distribution.
# Once we have these two statistics, we have to implement the sampling phase. Keras does not provide any predefined method to perform this operation, therefore we have to define it. With the aim to be consistent with the layer-composition paradigm used by Keras in defining a model, we define a Sampling layer as a new layer.
#
# In our case, the Sampling layer has in input the tuple made of the mean and the log-variance, and it has to compute the sample $z$ from them by exploiting the reparameterization trick:
# $$
# z=z_{mean} + exp(z_{var}/2) * \epsilon
# $$
# The reparameterization trick is used in VAE because it actually helps in the backpropagation process. Specifically, $\epsilon \sim \mathcal{N}(0,1)$ actually reparameterizes our VAE network. This allows the mean and log-variance vectors to still remain as the learnable parameters of the network while  maintaining the stochasticity of the entire system via epsilon.
#
#
# As usual, we will provide the structure of the implementation of the VAE in PyTorch. The Encoder and Decoder are embodied by the `E_layers` and `D_layers` respectively.<br>
#
# <br>
#
# **[TO COMPLETE]** Complete the code of the VAE model defining:
#
# 1. the dense layers that model `z_mean` and `z_var`
# 2. the sampling function that implements the reparametrization trick
# 3. the reparameterization trick in the forward function.
#
# *Hint*: to generate random values from a normal distribution you can use the PyTorch [torch.randn](https://pytorch.org/docs/stable/generated/torch.randn.html) function, and make sure the output shape is the proper one.

# %% [markdown]
# `%STARTCODE%`

# %%
class VAE(nn.Module):
  def __init__(self, input_dim, ENC_LAYERS, latent_dim, DEC_LAYERS, act_fun, last_layer_act_fun):
    super().__init__()
  
    self.E_layers = nn.ModuleList()
    self.D_layers = nn.ModuleList()
    self.latent_dim = latent_dim

    activation_functions = {'linear':transforms.Lambda(lambda x: x), 'sigmoid':F.sigmoid, 'relu':F.relu, 'tanh': F.tanh, 'leaky_relu': F.leaky_relu}
    assert act_fun in activation_functions, f'Activation Functions: {activation_functions.keys()}'
    self.af = activation_functions[act_fun]
    self.last_af = activation_functions[last_layer_act_fun]

    for layer_idx in range(len(ENC_LAYERS)):
      if layer_idx == 0:  # first layer, from input to enc
        self.E_layers = self.E_layers.append(nn.Linear(input_dim, ENC_LAYERS[layer_idx]))
      else:  # hidden layers, depending on the input
        self.E_layers = self.E_layers.append(nn.Linear(ENC_LAYERS[layer_idx-1], ENC_LAYERS[layer_idx]))
    
    ### TO COMPLETE
    # 1. define the dense layers that model z_mean and z_var
    self.linear_mean = nn.Linear(ENC_LAYERS[-1], latent_dim)
    self.linear_var = nn.Linear(ENC_LAYERS[-1], latent_dim)
    ###

    if len(DEC_LAYERS) == 0:
      self.D_layers = self.D_layers.append(nn.Linear(ENC_LAYERS[-1], input_dim))
    else:
      for layer_idx in range(len(DEC_LAYERS)):
        if layer_idx == 0:  # first layer, from enc to dec
          self.D_layers = self.D_layers.append(nn.Linear(latent_dim, DEC_LAYERS[layer_idx]))
        else:  # hidden layers, depending on the input
          self.D_layers = self.D_layers.append(nn.Linear(DEC_LAYERS[layer_idx-1], DEC_LAYERS[layer_idx]))

    self.final_fc = nn.Linear(DEC_LAYERS[-1], input_dim)
  
  def sampling(self, z_mean, z_var):
    ### TO COMPLETE
    # 2. write the sampling function that implements the reparametrization trick
    epsilon = torch.randn(list(z_mean.size()))
    z = z_mean + torch.exp(z_var/2) * epsilon
    return z
    ###

  def encode(self, x):
    """This function implmements the encoder part of our VAE.
    It will also be useful to explore the latent space learned after training!
    """
    for layer in self.E_layers:
      x = self.af(layer(x))
    return x

  def decode(self, z):
    """This function implemements the decoder part of our VAE.
    It will also be useful to explore the latent space learned after training!
    """
    for layer in self.D_layers:
      z = self.af(layer(z))
    
    out = self.final_fc(z)

    return self.last_af(out)
  
  def forward(self, x):
    x = self.encode(x)

    ### TO COMPLETE
    # 3. use the linear layers and the sampling function you defined above
    # to compute the sample z
   
    self.z_mean = z_mean = self.linear_mean(x)
    self.z_var  = z_var =self.linear_var(x)
    self.z = self.sampling(z_mean, z_var)
    
    ###

    return self.decode(self.z)

# %% [markdown]
# `%ENDCODE%`

# %% [markdown]
# #[TO COMPLETE] Loss Functions
#
# Now we have defined the VAE but, since it is a generative model, we have to define an ad-hoc training phase. Specifically, we have to manage the two losses used for this model. Indeed the parameters of a VAE are trained via two loss functions: a reconstruction loss, that forces the decoded samples to match the initial inputs, and a regularization loss that helps to learn  a well-formed latent space, and to reduce overfitting. The regularization loss is handled with the _Kullback-Liebler Divergence_. On the other hand, for the reconstruction loss we will use the _binary cross-entropy_ to compare each feature of a data point to the value in the reconstructed output.
#
# **[TO COMPLETE]**: Implement the reconstruction loss and the KL-divergence.
#
# *Disclaimer*: To implement the reconstruction loss you can use function or classes already available in PyTorch, while you must implement the KL-divergence from scratch, explointing the attributes in the `VAE` class.

# %% [markdown]
# `%STARTCODE%`

# %%
#let's define the reconstruction loss...
REC_LOSS = nn.BCELoss()

#..and the Kullback-Liebler Divergence
def KL_LOSS(model):
    
    #mean = model.linear_mean.weight
    #var = model.linear_var.weight
    mean = model.z_mean
    var =  model.z_var
    loss = -0.5 * torch.sum(1 + var - mean**2 - var.exp(), dim = 1)
    loss = torch.mean(loss)

    return loss
  ###

# %% [markdown]
# `%ENDCODE%`

# %% [markdown]
# #[TO COMPLETE] Training
#
# We define the training loop. Notice how we set a $\beta$ parameter to weight the combination of the two losses.

# %%
def train(model, optimizer, dataloader, epochs, Beta=1e-3):
  loss_train_rec, loss_train_kl, loss_train = [], [], []

  for epoch in range(epochs):
    model.train()
    n_train_batches, rec_train, kl_train, total_loss_train = 0, 0, 0, 0

    for idx, (img, _) in enumerate(dataloader):
      # reset the gradient for all parameters
      optimizer.zero_grad()
      
      # move the input to currently used device
      img = img.to(device)

      # run the model
      rec_img = model(img)
      
      # compute the loss for this sample
      rec_loss = REC_LOSS(rec_img, img)
      kl_loss = KL_LOSS(model)
      total_loss = rec_loss + Beta * kl_loss

      # accumulate the loss for this epoch
      total_loss_train += total_loss
      rec_train += rec_loss
      kl_train += kl_loss

      # compute the gradients and update weights
      total_loss.backward()
      optimizer.step()

      n_train_batches += 1

    # compute losses for this epoch
    avg_loss_train = total_loss_train/n_train_batches
    avg_rec_loss_train = rec_train/n_train_batches
    avg_kl_loss_train = kl_train/n_train_batches

    # store losses
    loss_train.append(avg_loss_train.item())
    loss_train_rec.append(avg_rec_loss_train.item())
    loss_train_kl.append(avg_kl_loss_train.item())

    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Loss: {avg_loss_train:.8f}", end=' ----- ')
      print(f"Rec Loss: {avg_rec_loss_train:.8f}", end=' ----- ')
      print(f"Effective KL Loss: {Beta * avg_kl_loss_train:.8f}")

  return loss_train, loss_train_rec, loss_train_kl

# %%
def plot_losses(loss_train, loss_rec, loss_kl):
  plt.subplot(2, 1, 1)
  plt.grid(True)
  plt.title("Reconstruction Loss")
  plt.plot(loss_rec)
  plt.xlabel("Epochs")
  plt.ylabel("Loss")
  plt.show()

  print("\n")

  plt.subplot(2, 1, 2)
  plt.title("KL Loss")
  plt.grid(True)
  plt.plot(loss_kl)
  plt.xlabel("Epochs")
  plt.ylabel("Loss")
  plt.show()

# %% [markdown]
# **[TO COMPLETE]:**
# Your task is to make the VAE working well and learn the digits'representstions. Define the hyperparameters for the encoder and decoder layers. Explain choice for what concerns the number of layers, the layers sizes, and the activation functions in the cells below.
#
# _Hint:_ Note that we should define the `latent_dim` (that is the dimension of $z$) to $2$. This choice is made to make possible to represent the results graphically.
# Pay attention to the relation between the decoding and encoding layers.

# %% [markdown]
# `%STARTCODE%`

# %%
### TO COMPLETE
# ENC_LAYERS and DEC_LAYERS should be lists describing the number and size of 
# encoding / decoding layers
input_dim = images.shape[-1] 
ENC_LAYERS =  [512,256] 
latent_dim = 2
DEC_LAYERS =  [256]
act_fun = 'sigmoid' 
last_layer_act_fun = 'sigmoid' 


vae = VAE(input_dim, ENC_LAYERS, latent_dim, DEC_LAYERS, act_fun, last_layer_act_fun).to(device)
summary(vae, input_size=(input_dim, ))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VAE                                      [784]                     --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [512]                     401,920
# │    └─Linear: 2-2                       [256]                     131,328
# ├─Linear: 1-2                            [2]                       514
# ├─Linear: 1-3                            [2]                       514
# ├─ModuleList: 1-4                        --                        --
# │    └─Linear: 2-3                       [256]                     768
# ├─Linear: 1-5                            [784]                     201,488
# ==========================================================================================
# Total params: 736,532
# Trainable params: 736,532
# Non-trainable params: 0
# Total mult-adds (M): 397.57
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 2.95
# Estimated Total Size (MB): 2.96
# ==========================================================================================

# %% [markdown]
# Let's train out model:

# %%
lr = 1e-3
epochs = 30

optimizer = torch.optim.Adam(vae.parameters(), lr=lr)

# %%
start = timer()
loss_train, loss_rec, loss_kl = train(vae, optimizer, dataloader, epochs)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Loss: 0.25112584 ----- Rec Loss: 0.24754059 ----- Effective KL Loss: 0.00358535
# epoch: 2 -> Loss: 0.22856070 ----- Rec Loss: 0.22411212 ----- Effective KL Loss: 0.00444856
# epoch: 3 -> Loss: 0.22510430 ----- Rec Loss: 0.22044036 ----- Effective KL Loss: 0.00466403
# epoch: 4 -> Loss: 0.22143804 ----- Rec Loss: 0.21648784 ----- Effective KL Loss: 0.00495010
# epoch: 5 -> Loss: 0.21628864 ----- Rec Loss: 0.21084583 ----- Effective KL Loss: 0.00544273
# epoch: 6 -> Loss: 0.21189857 ----- Rec Loss: 0.20620656 ----- Effective KL Loss: 0.00569202
# epoch: 7 -> Loss: 0.20889015 ----- Rec Loss: 0.20305397 ----- Effective KL Loss: 0.00583629
# epoch: 8 -> Loss: 0.20656475 ----- Rec Loss: 0.20061997 ----- Effective KL Loss: 0.00594488
# epoch: 9 -> Loss: 0.20441259 ----- Rec Loss: 0.19835001 ----- Effective KL Loss: 0.00606262
# epoch: 10 -> Loss: 0.20265745 ----- Rec Loss: 0.19650628 ----- Effective KL Loss: 0.00615102
# epoch: 11 -> Loss: 0.20099993 ----- Rec Loss: 0.19475512 ----- Effective KL Loss: 0.00624494
# epoch: 12 -> Loss: 0.19954184 ----- Rec Loss: 0.19324365 ----- Effective KL Loss: 0.00629807
# epoch: 13 -> Loss: 0.19826379 ----- Rec Loss: 0.19192035 ----- Effective KL Loss: 0.00634336
# epoch: 14 -> Loss: 0.19719300 ----- Rec Loss: 0.19078760 ----- Effective KL Loss: 0.00640548
# epoch: 15 -> Loss: 0.19622767 ----- Rec Loss: 0.18977034 ----- Effective KL Loss: 0.00645719
# epoch: 16 -> Loss: 0.19527921 ----- Rec Loss: 0.18875696 ----- Effective KL Loss: 0.00652224
# epoch: 17 -> Loss: 0.19441508 ----- Rec Loss: 0.18786639 ----- Effective KL Loss: 0.00654865
# epoch: 18 -> Loss: 0.19364248 ----- Rec Loss: 0.18705070 ----- Effective KL Loss: 0.00659180
# epoch: 19 -> Loss: 0.19300456 ----- Rec Loss: 0.18639575 ----- Effective KL Loss: 0.00660881
# epoch: 20 -> Loss: 0.19213367 ----- Rec Loss: 0.18547423 ----- Effective KL Loss: 0.00665944
# epoch: 21 -> Loss: 0.19138491 ----- Rec Loss: 0.18469258 ----- Effective KL Loss: 0.00669233
# epoch: 22 -> Loss: 0.19084014 ----- Rec Loss: 0.18411115 ----- Effective KL Loss: 0.00672886
# epoch: 23 -> Loss: 0.19024186 ----- Rec Loss: 0.18348819 ----- Effective KL Loss: 0.00675349
# epoch: 24 -> Loss: 0.18960883 ----- Rec Loss: 0.18282126 ----- Effective KL Loss: 0.00678767
# epoch: 25 -> Loss: 0.18904808 ----- Rec Loss: 0.18224384 ----- Effective KL Loss: 0.00680429
# epoch: 26 -> Loss: 0.18855073 ----- Rec Loss: 0.18173710 ----- Effective KL Loss: 0.00681367
# epoch: 27 -> Loss: 0.18804686 ----- Rec Loss: 0.18121570 ----- Effective KL Loss: 0.00683143
# epoch: 28 -> Loss: 0.18767567 ----- Rec Loss: 0.18082684 ----- Effective KL Loss: 0.00684886
# epoch: 29 -> Loss: 0.18721764 ----- Rec Loss: 0.18037060 ----- Effective KL Loss: 0.00684714
# epoch: 30 -> Loss: 0.18670583 ----- Rec Loss: 0.17981490 ----- Effective KL Loss: 0.00689080
# Training time in second: 362.52855270000146

# %%
plot_losses(loss_train, loss_rec, loss_kl)

# %% [markdown]
# `%ENDCODE%`

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# **[TO COMPLETE]** Comment on your choice of number of layers, the layers sizes, and the activation functions.
#
# Answer:
#
# I decided to keep 2 layers for the encoder and one for the decoder to avoid increasing hte complexity of the model unnecessarily. For the layer sizes, I initially chose a larger size of 512 and gradually reduced it, in order to extract more abstract representations. The decoder should set at 256, to match the last layer of the encoder. This ensures the symmetry between encoding and decoding. As for the activation function decided to use sigmoid. This choice was based on the experiments conducted, where the plot of representations in the latent spase appeared centered without too much overlaps. The last layer activation function in the decoder is set to sigmoid, as we need to map the output vlues to the range [0,1].

# %% [markdown]
# `%ENDTEXT`

# %% [markdown]
# #[TO COMPLETE] Generation
#
# The best part about generative models is that they can generate new data (ChatGPT is pretty good at it 🙃). We can therefore plot an example of the data generation by using the decoder part. Since we used a 2D latent space let's generate sevral possibile 2D $\hat{z}$ samples and pass them to our decoder. With the $scale$ parameter we can define the interval from where the entries of $\hat{z}$ are chosen, and with parameter $n$ it is possibile to define how many samples are generated.

# %%
def plot_latent(decoder, scale=2.0, n = 30):
     
    digit_size = 28
    figsize = 15
    figure = np.zeros((digit_size * n, digit_size * n))

    # here we systematically generate 2D samples of z_hat...
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            # ...we cast and reshape the samples
            z_sample = torch.tensor([[xi, yi]], dtype=torch.float32).to(device)
            # ...and then we pass them to the decoder, 
            # without keeping track of the gradient
            with torch.no_grad():
              x_decoded = vae.decode(z_sample)
            digit = x_decoded[0].reshape(digit_size, digit_size).to('cpu')
            figure[
                i * digit_size : (i + 1) * digit_size,
                j * digit_size : (j + 1) * digit_size,
            ] = digit

    # Finally we plot the generated data
    plt.figure(figsize=(figsize, figsize))
    start_range = digit_size // 2
    end_range = n * digit_size + start_range
    pixel_range = np.arange(start_range, end_range, digit_size)
    sample_range_x = np.round(grid_x, 1)
    sample_range_y = np.round(grid_y, 1)

    plt.xticks(pixel_range, sample_range_x)
    plt.yticks(pixel_range, sample_range_y)
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent(vae.D_layers, 2.0, 30)

# %% [markdown]
# The final result is quite impressive, considering that all these digits are artificial and they not belong to any dataset!
# Let's finally check how the various digits have been represented in the latent space by the VAE.

# %%
x_train, y_train = next(iter(DataLoader(MNIST, batch_size=len(MNIST))))

# %%
def plot_label_clusters(data, labels):
    with torch.no_grad():
      # let's compute the encodings 
      encoding = vae.encode(data.to(device))
      # and then the mean used in the reparameterization trick
      z_mean = vae.linear_mean(encoding).to('cpu')
    
    # Let's plot the latent space
    plt.figure(figsize=(12, 10))
    plt.scatter(z_mean[:, 0], z_mean[:, 1], c=labels)
    plt.colorbar()
    plt.xlabel("z_mean[0]")
    plt.ylabel("z_mean[1]")
    plt.show()

plot_label_clusters(x_train, y_train)

# %% [markdown]
# **[TO COMPLETE]** Explore how the hyper-parameters of the VAE (number of layers, layer sizes, etc.) influence the final result. Discuss the obtained plots, and different hyperparameters you have tried. Insert your discussion below:

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# Answer:
#
# Below is the list of all the experiments I have done:
#
# Experiment 1:
#
# ENC_LAYERS =  [128,64]
# latent_dim = 2
# DEC_LAYERS =  [64]
# act_fun = 'sigmoid'
# last_layer_act_fun = 'sigmoid'
#
# Overall loss: 0.195 - rec loss: 0.189 effective kl loss: 0.0060
#
# Experiment 2:
#
# ENC_LAYERS =  [128,64]
# latent_dim = 2
# DEC_LAYERS =  [64]
# act_fun = 'relu'
# last_layer_act_fun = 'sigmoid'
#
# Overall loss: 0.190 - rec loss: 0.184 effective kl loss: 0.0063
#
# Experiment 3:
#
# ENC_LAYERS =  [512, 256]
# latent_dim = 2
# DEC_LAYERS =  [256]
# act_fun = 'sigmoid'
# last_layer_act_fun = 'sigmoid'
#
# Overall loss: 0.1858 - rec loss: 0.1789 effective kl loss: 0.00687
#
# Experiment 4:
#
# ENC_LAYERS =  [512,256]
# latent_dim = 2
# DEC_LAYERS =  [256]
# act_fun = 'relu'
# last_layer_act_fun = 'sigmoid'
#
# Overall loss: 0.1848 - rec loss: 0.1781 effective kl loss: 0.0066
#
#
#
# Experiment 5:
#
# ENC_LAYERS =  [512,256, 128]
# latent_dim = 2
# DEC_LAYERS =  [128, 256]
# act_fun = 'sigmoid'
# last_layer_act_fun = 'sigmoid'
#
# Overall loss: 0.20 - rec loss: 0.1959 effective kl loss: 0.0041
#
#
# Experiment 6:
#
# ENC_LAYERS =  [512,256, 128]
# latent_dim = 2
# DEC_LAYERS =  [128, 256]
# act_fun = 'relu'
# last_layer_act_fun = 'sigmoid'
#
# Overall loss: 0.175 - rec loss: 0.168 effective kl loss: 0.0069
#
# Effect of the number of layers:
#
# Increasing the number of layers from 2 to 3 shows a slighlty higher overall loss. In terms of latent space plot, the additional layer seems to introduce more overlaps and sparsity. In experiment 5, for example, the plot exhibits a continous z-shape, with points being very closed to each other.
#
# Effect of layer size:
#
# We can see that larger layer size has a slightly lower overall loss. In terms of the latent space plot, larger layer sizes tend to result in better discrimination between numbers. The representation becomes more separable.
#
# Effect of activation function:
#
# Overall, using ReLU as activation function, we can see that we achieve a slightly lower overall loss. However, the latent space representation becomes sparser.

# %% [markdown]
# `%ENDTEXT`
