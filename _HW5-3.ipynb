# %% [markdown]
# # **Deep Learning Homework 5: *Autoencoders***
# ### MSc Computer Science, Data Science, Cybersecurity Computer Engeneering @UniPD
# ### 2nd semester - 6 ECTS
# ### Prof. Alessandro Sperduti & Prof. Nicolò Navarin and Dr. Luca Pasa
# ---
#
#
# In this homework, we will deal with _dimensionality reduction_ and learn how to develop a simple _Autoencoder_.
# In the first part, we will learn how to develop a simple shallow autoencoder, then we will develop a deep version. Finally, we will experiment with the application of autoencoder on denoising data task (denoising-autoencoder).

# %% [markdown]
# #Requirements

# %%
# !pip3 install datasets skorch pandas~=1.5 torch~=1.13 torchinfo torchdata~=0.5 torchtext~=0.14 torchvision~=0.14 torchaudio~=0.13
# Out:
# Requirement already satisfied: datasets in c:\users\roven\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: skorch in c:\users\roven\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: pandas~=1.5 in c:\users\roven\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: torch~=1.13 in c:\users\roven\anaconda3\lib\site-packages (1.13.1)
# Requirement already satisfied: torchinfo in c:\users\roven\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: torchdata~=0.5 in c:\users\roven\anaconda3\lib\site-packages (0.5.1)
# Requirement already satisfied: torchtext~=0.14 in c:\users\roven\anaconda3\lib\site-packages (0.14.1)
# Requirement already satisfied: torchvision~=0.14 in c:\users\roven\anaconda3\lib\site-packages (0.14.1)
# Requirement already satisfied: torchaudio~=0.13 in c:\users\roven\anaconda3\lib\site-packages (0.13.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (2.26.0)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (11.0.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (0.13.4)
# Requirement already satisfied: multiprocess in c:\users\roven\anaconda3\lib\site-packages (from datasets) (0.70.14)
# Requirement already satisfied: packaging in c:\users\roven\anaconda3\lib\site-packages (from datasets) (21.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (0.3.6)
# Requirement already satisfied: xxhash in c:\users\roven\anaconda3\lib\site-packages (from datasets) (3.2.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (6.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (2023.3.0)
# Requirement already satisfied: aiohttp in c:\users\roven\anaconda3\lib\site-packages (from datasets) (3.8.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (1.22.4)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (4.62.3)
# Requirement already satisfied: responses<0.19 in c:\users\roven\anaconda3\lib\site-packages (from datasets) (0.18.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\roven\anaconda3\lib\site-packages (from skorch) (0.24.2)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\roven\anaconda3\lib\site-packages (from skorch) (0.9.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\roven\anaconda3\lib\site-packages (from skorch) (1.7.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\roven\anaconda3\lib\site-packages (from pandas~=1.5) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\roven\anaconda3\lib\site-packages (from pandas~=1.5) (2.8.2)
# Requirement already satisfied: typing_extensions in c:\users\roven\anaconda3\lib\site-packages (from torch~=1.13) (3.10.0.2)
# Requirement already satisfied: urllib3>=1.25 in c:\users\roven\anaconda3\lib\site-packages (from torchdata~=0.5) (1.26.7)
# Requirement already satisfied: portalocker>=2.0.0 in c:\users\roven\anaconda3\lib\site-packages (from torchdata~=0.5) (2.7.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\roven\anaconda3\lib\site-packages (from torchvision~=0.14) (8.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\roven\anaconda3\lib\site-packages (from aiohttp->datasets) (21.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\roven\anaconda3\lib\site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\roven\anaconda3\lib\site-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\roven\anaconda3\lib\site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\roven\anaconda3\lib\site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\roven\anaconda3\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\roven\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: filelock in c:\users\roven\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.3.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\roven\anaconda3\lib\site-packages (from packaging->datasets) (3.0.4)
# Requirement already satisfied: pywin32>=226 in c:\users\roven\anaconda3\lib\site-packages (from portalocker>=2.0.0->torchdata~=0.5) (228)
# Requirement already satisfied: six>=1.5 in c:\users\roven\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas~=1.5) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\roven\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\roven\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\roven\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->skorch) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\roven\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->skorch) (1.1.0)
# Requirement already satisfied: colorama in c:\users\roven\anaconda3\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.4)

# %% [markdown]
# #Imports

# %%
import torch
from torch import nn
import torch.nn.functional as F
from torchinfo import summary
from torchvision.datasets import CIFAR10
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader, random_split
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from timeit import default_timer as timer
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Loading
#
# We load the `CIFAR-10 dataset`, available from `torchvision.datasets`. This dataset is one of the most popular benckmark in the filed of Computer Vision. It consits of $10$ different classes, that represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. The dataset contains $50,000$ training images and $10,000$ images for testing.
#
# First, we will pre-process them with a `PreProcessing` fuction that works in the following way. The images are originally in RGB format, but we will convert them to grayscale for convenience. The value of each pixel is between $0$ and $255$, and it represents a point of an image of size $32\times32$. We will normalize all values between $0$ and $1$, and we will flatten the $32\times32$ images into vectors of size $1024$.
# Moreover, since no validation set is defined, we split the train set in a validation set and a new test set.
# Finally, we design a custom dataset class, derived from the standard `Dataset` class, that returns a PyTorch Dataset object, along with its noisy version. The Gaussian noise is tunable with the `noise_factor` parameter and will be used for the Denoising Autoencoder.

# %%
to_tensor = transforms.ToTensor()

def PreProcessing(img):
  img = to_tensor(img) #PIL to tensor + Scaling
  img = torch.mean(img, 0) #One channel averaged over the colors
  img = img.reshape(torch.prod(torch.tensor(img.shape))) #Flattening
  return img.to(torch.float32)

# %%
dataset = CIFAR10(root='data/', download=True, train=True, transform=transforms.Lambda(PreProcessing)) # 50000 samples
test_data = CIFAR10(root='data/', download=True, train=False, transform=transforms.Lambda(PreProcessing)) # 10000 samples
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
val_size = 10000
train_size = len(dataset) - val_size

train_data, val_data = random_split(dataset, [train_size, val_size])
print(f"Training samples = {len(train_data)} \nValidation samples = {len(val_data)} \nTest samples = {len(test_data)}")
# Out:
# Training samples = 40000
# Validation samples = 10000
# Test samples = 10000

# %%
class CustomDataset(Dataset):
  def __init__(self, dataset, noise_factor, device='cpu'):
    super().__init__()
    self.dataset = dataset
    self.nf = noise_factor
  def __len__(self):
    return len(self.dataset)
  def __getitem__(self, idx):
    x, _ = self.dataset[idx]
    x_noisy = x + self.nf*np.random.normal(loc=0.0, scale=1.0, size=x.shape)
    x_noisy = np.clip(x_noisy, 0., 1.).to(torch.float32)
    return (x.to(device), x_noisy.to(device))

# %%
# Set niose factor for later
noise_factor = 0.1

# %% [markdown]
# # [TO COMPLETE] SVD
#
# Similar to Principal component analysis (PCA), Singular Value Decomposition (SVD) is a standard linear dimensionality reduction method. They both linearly combine the features of the original high-dimensional dataset and project them into a lower-dimensional space, ideally retaing most of thier intrinsic properties.
#
# In this first part of the HW, we will focus our attention on SVD decomposition and its performances. Given a matrix $X$, the SVD decomposes it into the product of two unitary matrices, $V$ and $U$, and a rectangular diagonal matrix of singular values $S$:
#
# $$ X=V \cdot S \cdot U^T.$$
#
# The SVD is already implemented in PyTorch as `torch.linalg.svd`. In our case, the $X$ matrix will represent the training set, where each row is a sample (therefore the number of columns will be the number of input features). However, notice that the $X$ matrix has a huge number of rows (we have 50,000 input samples) and only 784 columns. If you are using the _Colab_ free plan, the quantity of available RAM may not be sufficient to compute the SVD of $X$. Therefore, to ease memory consumption and numerical stability, we resort to one property of the SVD and compute its equivalent version from the matrix $C= X^T \cdot X$, that can be decomposed as:
#
# $$ C= U \cdot S^2 \cdot U^T$$
#
# Since we need just the matrix $U$ to compute the compressed version of our data, this trick turns out to be a quick and good solution.

# %%
def svd_k(X, k):
  # k: sets the number of components to keep

  # Compute the matrix C
  C = torch.matmul(X.T, X)
  # SVD decomposition
  U, s_sqr, U_T = torch.linalg.svd(C)
  # Limit the number columns of U to k
  U_k = U[:,:k]
  return U_k

# %% [markdown]
# Now we create the dataset ready for the SVD:

# %%
device = torch.device("cpu") #for SVD

x_train, x_train_noisy = next(iter(DataLoader(CustomDataset(train_data, noise_factor, device), batch_size=len(train_data))))
x_val, x_val_noisy = next(iter(DataLoader(CustomDataset(val_data, noise_factor, device), batch_size=len(val_data))))
x_test, x_test_noisy = next(iter(DataLoader(CustomDataset(test_data, noise_factor, device), batch_size=len(test_data))))

x_train.shape, x_train_noisy.shape, x_val.shape, x_val_noisy.shape, x_test.shape, x_test_noisy.shape
# Out:
# (torch.Size([40000, 1024]),
#  torch.Size([40000, 1024]),
#  torch.Size([10000, 1024]),
#  torch.Size([10000, 1024]),
#  torch.Size([10000, 1024]),
#  torch.Size([10000, 1024]))

# %% [markdown]
# Let's define the ENCODING_DIM, that will be the size of the compressed version of input data. And compute the compressed version of the training set and test set.

# %%
ENCODING_DIM = 160

U_k = svd_k(x_train, ENCODING_DIM)

x_training_svd = torch.matmul(x_train, U_k)
x_test_svd = torch.matmul(x_test, U_k)

# %% [markdown]
# We now reconstruct back the original input and check how much information was lost due to the compression. We do so by computing the mean squared error between the original input and the reconstruction, and by plotting the reconstructed images.

# %%
x_training_reco = torch.matmul(x_training_svd, U_k.T)
x_test_reco = torch.matmul(x_test_svd, U_k.T)

# %%
accuracy_train = ((x_train - x_training_reco)**2).mean()
accuracy_test = ((x_test - x_test_reco)**2).mean()

print("Training mse: %.5f" % ( accuracy_train))
print("Test mse: %.5f" % ( accuracy_test))
# Out:
# Training mse: 0.00276
# Test mse: 0.00279

# %%
def plot_img(n, images_sets: list, title=""):
  plt.figure(figsize=(20, 4))
  for i in range(n):
    for set_idx, images in enumerate(images_sets):
      ax = plt.subplot(len(images_sets), n, i + 1 + set_idx*n)
      plt.imshow(images[i].reshape(32, 32))
      plt.gray()
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)
  plt.suptitle(title)
  plt.show()

# %% [markdown]
# Let's see how well the input can be reconstructed by displaying a few of the input images and the corresponding reconstructions. Obviously, all these evaluations have to be done on the test set.
#
# The first row of images corresponds to input data, while the second one contains the reconstructions.

# %%
_ = plot_img(10, [x_test, x_test_reco], title="Original (top) vs reconstruction (bottom)")

# %% [markdown]
# **[TO COMPLETE]**: What happens by varying the ENCODING_DIM?
#  Test and discuss the results in a cell below.

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# **ANSWER**:
#
# The model has difficulty encoding the characteristics of the data at lower values of the encoding dimension, such as 32. The reconstructed images are therefore of low quality. But as we increase the encoding dimension to 64 and 128, the reconstructed images get better and are able to effectively capture the key aspects of the data. The MSE reduces from 0.009 for an encoding size of 32 to 0.006 for 64, and eventually reaches 0.003 for an encoding dimension of 128 to demonstrate this improvement.

# %% [markdown]
# `%ENDEXT`

# %% [markdown]
# # [TO COMPLETE] Shallow Linear Autoencoder

# %% [markdown]
# Let's define a model that consists of a single fully-connected neural layer. The hidden layer and the output layer act as the encoder and the decoder, respectively. First, we define the `DataLoader` to train the model.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_size = 512
noise_factor = 0.1 # adjust the noise level here.

dataloader_train_AE = DataLoader(CustomDataset(train_data, noise_factor, device), batch_size = batch_size)
dataloader_val_AE = DataLoader(CustomDataset(val_data, noise_factor, device), batch_size = batch_size)
dataloader_test_AE = DataLoader(CustomDataset(test_data, noise_factor, device), batch_size = batch_size)

# %% [markdown]
# Then, we build our shallow Autoencoder. Here's a breakdown of the code to help you grasp how it works:
#
# 1. The `__init__` method is the initialization function for the Auto_Encoder class. It takes four parameters: `input_dim` (dimensionality of the input data), `enc_layers` (a list specifying the sizes of the encoder layers), `dec_layers` (a list specifying the sizes of the decoder layers), and `act_fun` (the activation function to be used).
#
# 2. The `nn.ModuleList()` is used to create empty lists E_layers and D_layers to store the encoder and decoder layers, respectively.
#
# 3. The `for loop `iterates over the `enc_layers` list to create the encoder layers. For the first layer, it creates a linear layer (`nn.Linear`) mapping from the input dimension to the size of the first encoder layer. For subsequent layers, it creates linear layers mapping between consecutive encoder layer sizes. The created layers are appended to the `self.E_layers` list.
#
# 4. The code then checks if the `dec_layers` list is empty. If it is empty, it creates a single linear layer mapping from the last encoder layer size to the input dimension (remember: the goal of the AE is to reconstruct the input). Otherwise, it iterates over the `dec_layers` list to create the decoder layers, similar to how the encoder layers were created. The last decoder layer is always mapped to the input dimension.
#
# 5. The `_init_weights` method is a helper function that initializes the weights of the linear layers. It is applied to all modules (layers) of the Auto_Encoder instance.
#
# 6. The `forward` method defines the forward pass of the Autoencoder.

# %%
class Auto_Encoder(nn.Module):
  
  def __init__(self, input_dim, enc_layers, dec_layers, act_fun):
    super().__init__()

    self.E_layers = nn.ModuleList()
    self.D_layers = nn.ModuleList()
    self.act_fun = act_fun
    activation_functions = {'linear': transforms.Lambda(lambda x: x),
                            'sigmoid': F.sigmoid,
                            'relu': F.relu,
                            'tanh': F.tanh,
                            'leaky_relu': F.leaky_relu}
    assert self.act_fun in activation_functions, f'Activation Functions: {activation_functions.keys()}'
    self.af = activation_functions[self.act_fun]

    for layer_idx in range(len(enc_layers)):
      if layer_idx == 0:  # first layer, from input to enc
        self.E_layers = self.E_layers.append(nn.Linear(input_dim, enc_layers[layer_idx]))
      else:  # hidden layers, depending on the input
        self.E_layers = self.E_layers.append(nn.Linear(enc_layers[layer_idx-1], enc_layers[layer_idx]))

    if len(dec_layers) == 0:
      self.D_layers = self.D_layers.append(nn.Linear(enc_layers[-1], input_dim))
    else:
      for layer_idx in range(len(dec_layers)):
        if layer_idx == 0:  # first layer, from enc to dec
          self.D_layers = self.D_layers.append(nn.Linear(enc_layers[-1], dec_layers[layer_idx]))
        else:  # hidden layers, depending on the input
          self.D_layers = self.D_layers.append(nn.Linear(dec_layers[layer_idx-1], dec_layers[layer_idx]))
    
      self.D_layers = self.D_layers.append(nn.Linear(dec_layers[-1], input_dim)) # final output layer
    
    self.apply(self._init_weights)
    
  def _init_weights(self, module):
    if isinstance(module, nn.Linear):
        module.weight.data.normal_(mean=0.0, std=.1)
        if module.bias is not None:
            module.bias.data.zero_()
  
  def forward(self, x):
    for layer in self.E_layers:
      x = self.af(layer(x))
    for layer in self.D_layers[:-1]:
      x = self.af(layer(x))
    if self.act_fun == 'linear':
      return self.D_layers[-1](x)
    else:
      return F.sigmoid(self.D_layers[-1](x)) #last act func is always sigmoid

# %% [markdown]
# **[TO COMPLETE]** Check the results and compare them with the ones obtained with the SVD. In the cell at the end of this section (after the result of the linear autoencoder), give an explanation of the relation between the results obtained  by the shallow linear autoencoder and the ones obtained by the SVD decomposition.
#
# Try also to be aquainted with the usual PyTorch training and evaluation routines. In the following part of the HW, the more training epochs the better the resutls, but it will also take longer. Feel free to change the `epochs` variable, just be consistent to make fair comparisons.

# %%
IN_DIM = x_train.shape[-1]
ENC_LAYERS = [256] 
DEC_LAYERS = [] 
ACT_FUN = 'linear'
lr = 0.005
epochs = 30 # Feel free to lower this to speed up the training times. Nevertheless, do not go below 25 epochs.

Shallow_AE = Auto_Encoder(IN_DIM, ENC_LAYERS, DEC_LAYERS, ACT_FUN).to(device)
summary(Shallow_AE, input_size=(batch_size, IN_DIM))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Auto_Encoder                             [512, 1024]               --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [512, 256]                262,400
# ├─ModuleList: 1-2                        --                        --
# │    └─Linear: 2-2                       [512, 1024]               263,168
# ==========================================================================================
# Total params: 525,568
# Trainable params: 525,568
# Non-trainable params: 0
# Total mult-adds (M): 269.09
# ==========================================================================================
# Input size (MB): 2.10
# Forward/backward pass size (MB): 5.24
# Params size (MB): 2.10
# Estimated Total Size (MB): 9.44
# ==========================================================================================

# %%
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(Shallow_AE.parameters(), lr=lr)

# %%
def train(model, optimizer, dataloader_train, dataloader_val, epochs, denoising=False):
  loss_train, loss_val = [], []
  for epoch in range(epochs):

    model.train()
    total_count_train, n_train_batches, total_loss_train = 0, 0, 0
    for idx, (x, x_noisy) in enumerate(dataloader_train):
      optimizer.zero_grad()
      if denoising:
        x_rec = model(x_noisy)
      else:
        x_rec = model(x)
      loss = criterion(x_rec, x)
      total_loss_train += loss
      loss.backward()
      optimizer.step()

      total_count_train += x.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    
    total_count_val, n_val_batches, total_loss_val = 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (x, x_noisy) in enumerate(dataloader_val):
            if denoising:
              x_rec = model(x_noisy)
            else:
              x_rec = model(x)

            loss = criterion(x_rec, x)
            total_loss_val += loss
            total_count_val += x.size(0)
            n_val_batches += 1

    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: Val_Loss: {avg_loss_val:.8f}")
  return loss_train, loss_val

# %%
start = timer()
loss_train, loss_val = train(Shallow_AE, optimizer, dataloader_train_AE,
                             dataloader_val_AE, epochs)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Loss: 0.86113393 ---------------- Val_Acc: Val_Loss: 0.24680123
# epoch: 2 -> Loss: 0.19215156 ---------------- Val_Acc: Val_Loss: 0.15727746
# epoch: 3 -> Loss: 0.12706232 ---------------- Val_Acc: Val_Loss: 0.10347363
# epoch: 4 -> Loss: 0.08552057 ---------------- Val_Acc: Val_Loss: 0.07499422
# epoch: 5 -> Loss: 0.06527559 ---------------- Val_Acc: Val_Loss: 0.05884638
# epoch: 6 -> Loss: 0.05210180 ---------------- Val_Acc: Val_Loss: 0.05118118
# epoch: 7 -> Loss: 0.04453208 ---------------- Val_Acc: Val_Loss: 0.03974663
# epoch: 8 -> Loss: 0.03586229 ---------------- Val_Acc: Val_Loss: 0.03412879
# epoch: 9 -> Loss: 0.03115989 ---------------- Val_Acc: Val_Loss: 0.02927080
# epoch: 10 -> Loss: 0.02674630 ---------------- Val_Acc: Val_Loss: 0.02592259
# epoch: 11 -> Loss: 0.02420564 ---------------- Val_Acc: Val_Loss: 0.02305579
# epoch: 12 -> Loss: 0.02107108 ---------------- Val_Acc: Val_Loss: 0.02096059
# epoch: 13 -> Loss: 0.01914853 ---------------- Val_Acc: Val_Loss: 0.01860787
# epoch: 14 -> Loss: 0.01724761 ---------------- Val_Acc: Val_Loss: 0.01706121
# epoch: 15 -> Loss: 0.01592521 ---------------- Val_Acc: Val_Loss: 0.01583091
# epoch: 16 -> Loss: 0.01470014 ---------------- Val_Acc: Val_Loss: 0.01443882
# epoch: 17 -> Loss: 0.01356257 ---------------- Val_Acc: Val_Loss: 0.01442179
# epoch: 18 -> Loss: 0.01298876 ---------------- Val_Acc: Val_Loss: 0.01274872
# epoch: 19 -> Loss: 0.01240446 ---------------- Val_Acc: Val_Loss: 0.01197263
# epoch: 20 -> Loss: 0.01102834 ---------------- Val_Acc: Val_Loss: 0.01140445
# epoch: 21 -> Loss: 0.01073988 ---------------- Val_Acc: Val_Loss: 0.01119712
# epoch: 22 -> Loss: 0.00998128 ---------------- Val_Acc: Val_Loss: 0.01058432
# epoch: 23 -> Loss: 0.00955555 ---------------- Val_Acc: Val_Loss: 0.00952622
# epoch: 24 -> Loss: 0.00903120 ---------------- Val_Acc: Val_Loss: 0.00921655
# epoch: 25 -> Loss: 0.00848276 ---------------- Val_Acc: Val_Loss: 0.00868885
# epoch: 26 -> Loss: 0.00829629 ---------------- Val_Acc: Val_Loss: 0.00906446
# epoch: 27 -> Loss: 0.00807829 ---------------- Val_Acc: Val_Loss: 0.00949815
# epoch: 28 -> Loss: 0.00751991 ---------------- Val_Acc: Val_Loss: 0.00815289
# epoch: 29 -> Loss: 0.00727077 ---------------- Val_Acc: Val_Loss: 0.00864326
# epoch: 30 -> Loss: 0.00694137 ---------------- Val_Acc: Val_Loss: 0.00703243
# Training time in second: 886.5934556000011

# %%
def plot_learning_acc_and_loss(loss_tr, loss_val):
    info = {'loss_training':loss_tr, 'loss_validation':loss_val}
    df = pd.DataFrame(info)
    df.plot(figsize=(10, 8), subplots=[('loss_training','loss_validation')], grid=True)
    plt.xlabel("Epochs")
    plt.show()

# %%
plot_learning_acc_and_loss(loss_train, loss_val)

# %%
def test(model, dataloader_test=dataloader_test_AE, denoising=False): #dataloader_test_AE not train
  model.eval()
  total_count_test, n_batches_test, loss = 0, 0, 0
  for idx, (x, x_noisy) in enumerate(dataloader_test):
      if denoising:
        x_rec = model(x_noisy)
      else:
        x_rec = model(x)
      loss += criterion(x_rec, x)
      total_count_test += x.size(0)
      n_batches_test += 1
  loss_test = loss/n_batches_test
  print(f"Test Loss: {loss_test:.8f}")

# %%
test(Shallow_AE)
# Out:
# Test Loss: 0.00700715

# %%
@torch.no_grad()
def apply_on_test(model, device, denoising=False):
  if denoising:
    x = x_test_noisy.to(device)
  else:
    x = x_test.to(device)
  for layer in model.E_layers:
      x = model.af(layer(x))
  encoded_imgs = x


  y = encoded_imgs
  for layer in model.D_layers[:-1]:
      y = model.af(layer(y))
  if model.act_fun == 'linear':
    decoded_imgs = model.D_layers[-1](y)
  else:
    decoded_imgs = F.sigmoid(model.D_layers[-1](y))

  return (encoded_imgs.to("cpu"), decoded_imgs.to("cpu"))

# %%
encoded_imgs, decoded_imgs = apply_on_test(model=Shallow_AE, device=device)

# %%
plot_img(10, [x_test, decoded_imgs], title="Original (top) vs reconstruction (bottom)")

# %% [markdown]
# Comment the results obtained with the shallow linear autoencoder in relation to the ones obtained by the SVD decomposition. Are they different or similar? Why do you think they are so? (hint: consider the theoretical relationship between SVD and a shallow linear autoencoder.)

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# **ANSWER**:
#
# From the theory, we know that when the decoder is linear and the loss function is the MSE, a shallow linear autoencoder behaves as PCA. The reconstruction are worst. Ths might be explained by the fact that the SVD's low-rank approximation captures the key information in the data, leading to better reconstruction quality.

# %% [markdown]
# `%ENDTEXT`

# %% [markdown]
# # [TO COMPLETE] Shallow non-linear Autoencoder

# %% [markdown]
# **[TO COMPLETE]** Replicate the code of the previous exercise but in this case, instead of using linear activation functions use non-linear ones. Choose the most appropriate non-linear function, and motivate your choice in the last cell of this section. Discuss the results you obtained in relation to those obtained with the Shallow Linear Autoencoder.

# %% [markdown]
# `%STARTCODE`

# %%
# [TO COMPLETE]
# define model and training hyperparameters
IN_DIM = x_train.shape[-1]
ENC_LAYERS = [256] 
DEC_LAYERS = [] 
ACT_FUN = 'sigmoid'
lr = 0.005
epochs = 30 # Feel free to lower this to speed up the training times. Nevertheless, do not go below 25 epochs.

Shallow_non_AE = Auto_Encoder(IN_DIM, ENC_LAYERS, DEC_LAYERS, ACT_FUN).to(device)
summary(Shallow_non_AE, input_size=(batch_size, IN_DIM))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Auto_Encoder                             [512, 1024]               --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [512, 256]                262,400
# ├─ModuleList: 1-2                        --                        --
# │    └─Linear: 2-2                       [512, 1024]               263,168
# ==========================================================================================
# Total params: 525,568
# Trainable params: 525,568
# Non-trainable params: 0
# Total mult-adds (M): 269.09
# ==========================================================================================
# Input size (MB): 2.10
# Forward/backward pass size (MB): 5.24
# Params size (MB): 2.10
# Estimated Total Size (MB): 9.44
# ==========================================================================================

# %%
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(Shallow_non_AE.parameters(), lr=lr)

# %%
start = timer()
loss_train, loss_val = train(Shallow_non_AE, optimizer, dataloader_train_AE,
                             dataloader_val_AE, epochs)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Loss: 0.04197658 ---------------- Val_Acc: Val_Loss: 0.02943198
# epoch: 2 -> Loss: 0.02376655 ---------------- Val_Acc: Val_Loss: 0.01956471
# epoch: 3 -> Loss: 0.01878268 ---------------- Val_Acc: Val_Loss: 0.01646396
# epoch: 4 -> Loss: 0.01516624 ---------------- Val_Acc: Val_Loss: 0.01387084
# epoch: 5 -> Loss: 0.01512451 ---------------- Val_Acc: Val_Loss: 0.01292535
# epoch: 6 -> Loss: 0.01224889 ---------------- Val_Acc: Val_Loss: 0.01151853
# epoch: 7 -> Loss: 0.01154368 ---------------- Val_Acc: Val_Loss: 0.01142349
# epoch: 8 -> Loss: 0.01081766 ---------------- Val_Acc: Val_Loss: 0.01019199
# epoch: 9 -> Loss: 0.01021938 ---------------- Val_Acc: Val_Loss: 0.01135561
# epoch: 10 -> Loss: 0.00993124 ---------------- Val_Acc: Val_Loss: 0.00967896
# epoch: 11 -> Loss: 0.00949292 ---------------- Val_Acc: Val_Loss: 0.01044388
# epoch: 12 -> Loss: 0.00921131 ---------------- Val_Acc: Val_Loss: 0.00988646
# epoch: 13 -> Loss: 0.00879472 ---------------- Val_Acc: Val_Loss: 0.01072960
# epoch: 14 -> Loss: 0.00876602 ---------------- Val_Acc: Val_Loss: 0.00830224
# epoch: 15 -> Loss: 0.00858025 ---------------- Val_Acc: Val_Loss: 0.00908244
# epoch: 16 -> Loss: 0.00837654 ---------------- Val_Acc: Val_Loss: 0.00956331
# epoch: 17 -> Loss: 0.00809598 ---------------- Val_Acc: Val_Loss: 0.01221378
# epoch: 18 -> Loss: 0.00815744 ---------------- Val_Acc: Val_Loss: 0.00784609
# epoch: 19 -> Loss: 0.00784281 ---------------- Val_Acc: Val_Loss: 0.00814752
# epoch: 20 -> Loss: 0.00782079 ---------------- Val_Acc: Val_Loss: 0.00751394
# epoch: 21 -> Loss: 0.00774374 ---------------- Val_Acc: Val_Loss: 0.00769625
# epoch: 22 -> Loss: 0.00772100 ---------------- Val_Acc: Val_Loss: 0.00742597
# epoch: 23 -> Loss: 0.00741032 ---------------- Val_Acc: Val_Loss: 0.00745398
# epoch: 24 -> Loss: 0.00758520 ---------------- Val_Acc: Val_Loss: 0.01023839
# epoch: 25 -> Loss: 0.00801525 ---------------- Val_Acc: Val_Loss: 0.00725487
# epoch: 26 -> Loss: 0.00721368 ---------------- Val_Acc: Val_Loss: 0.00724400
# epoch: 27 -> Loss: 0.00723090 ---------------- Val_Acc: Val_Loss: 0.00706631
# epoch: 28 -> Loss: 0.00715186 ---------------- Val_Acc: Val_Loss: 0.00694512
# epoch: 29 -> Loss: 0.00721560 ---------------- Val_Acc: Val_Loss: 0.00676582
# epoch: 30 -> Loss: 0.00700412 ---------------- Val_Acc: Val_Loss: 0.00688824
# Training time in second: 688.9636170000012

# %%
plot_learning_acc_and_loss(loss_train, loss_val)

# %%
test(Shallow_non_AE)
# Out:
# Test Loss: 0.00685413

# %%
encoded_imgs, decoded_imgs = apply_on_test(model=Shallow_non_AE, device=device)

plot_img(10, [x_test, decoded_imgs], title="Original (top) vs reconstruction (bottom)")

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# Discuss the results you obtained with the activation functions you have tested and also motivate your choice. Compare your results to the ones obtained with the Shallow Linear Autoencoder.

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# **ANSWER**:
#
# Following experiments with ReLU, tanh, and sigmoid activation functions, it was discovered that both ReLU and tanh suffered a loss of 0.01 on the test set, resulting in poor image reconstruction. The loss dropped to 0.006 when the sigmoid activation function was used, showing superior image reconstruction over the linear autoencoder. The choice of sigmoid as the activation function resulted in improved reconstruction performance, capturing the main features of the data more effectively.

# %% [markdown]
# `%ENDTEXT`

# %% [markdown]
# # [TO COMPLETE] Deep Autoencoder

# %% [markdown]
# **[TO COMPLETE]**: Define a deep version of the Autoeancoder defined above. The autoencoder has to **use at least $5$ layers**. The model will use 𝑛 layers for encoding, and $n-1$ for decoding. The layers sizes of the encoding part decrease at each layer (e.g. `IN_DIM` → $k$ → $k/2$, where $k/2$ is the arbitrarly chosen encoding dim). The decoding part layers dimensions progression turns out to be mirrored (i.e., $k$ → `IN_DIM`, the resulting overall structure recalls an hourglass!). Try different hyperparameters configurations and write a short report of your experiments below. Leave the best execution in the code cells.

# %% [markdown]
# `%STARTCODE`

# %%
# [TO COMPLETE]
# define model and training hyperparameters
IN_DIM = x_train.shape[-1]
ENC_LAYERS = [512, 256, 128] 
DEC_LAYERS = [256, 512] 
ACT_FUN = 'relu'
lr = 0.001
epochs = 40 # Feel free to lower this to speed up the training times. Nevertheless, do not go below 25 epochs.
# END

DEEP_non_AE = Auto_Encoder(IN_DIM, ENC_LAYERS, DEC_LAYERS, ACT_FUN).to(device)
summary(DEEP_non_AE, input_size=(batch_size, IN_DIM))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Auto_Encoder                             [512, 1024]               --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [512, 512]                524,800
# │    └─Linear: 2-2                       [512, 256]                131,328
# │    └─Linear: 2-3                       [512, 128]                32,896
# ├─ModuleList: 1-2                        --                        --
# │    └─Linear: 2-4                       [512, 256]                33,024
# │    └─Linear: 2-5                       [512, 512]                131,584
# │    └─Linear: 2-6                       [512, 1024]               525,312
# ==========================================================================================
# Total params: 1,378,944
# Trainable params: 1,378,944
# Non-trainable params: 0
# Total mult-adds (M): 706.02
# ==========================================================================================
# Input size (MB): 2.10
# Forward/backward pass size (MB): 11.01
# Params size (MB): 5.52
# Estimated Total Size (MB): 18.62
# ==========================================================================================

# %%
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(DEEP_non_AE.parameters(), lr=lr)

# %%
start = timer()
loss_train, loss_val = train(DEEP_non_AE, optimizer, dataloader_train_AE,
                             dataloader_val_AE, epochs)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Loss: 0.05419183 ---------------- Val_Acc: Val_Loss: 0.03834472
# epoch: 2 -> Loss: 0.03202357 ---------------- Val_Acc: Val_Loss: 0.02709024
# epoch: 3 -> Loss: 0.02413183 ---------------- Val_Acc: Val_Loss: 0.02286873
# epoch: 4 -> Loss: 0.02126991 ---------------- Val_Acc: Val_Loss: 0.02076856
# epoch: 5 -> Loss: 0.01986468 ---------------- Val_Acc: Val_Loss: 0.01927216
# epoch: 6 -> Loss: 0.01908852 ---------------- Val_Acc: Val_Loss: 0.01906380
# epoch: 7 -> Loss: 0.01902199 ---------------- Val_Acc: Val_Loss: 0.01891376
# epoch: 8 -> Loss: 0.01883940 ---------------- Val_Acc: Val_Loss: 0.01888236
# epoch: 9 -> Loss: 0.01883133 ---------------- Val_Acc: Val_Loss: 0.01880560
# epoch: 10 -> Loss: 0.01872334 ---------------- Val_Acc: Val_Loss: 0.01876400
# epoch: 11 -> Loss: 0.01869988 ---------------- Val_Acc: Val_Loss: 0.01869189
# epoch: 12 -> Loss: 0.01868434 ---------------- Val_Acc: Val_Loss: 0.01864610
# epoch: 13 -> Loss: 0.01860453 ---------------- Val_Acc: Val_Loss: 0.01868821
# epoch: 14 -> Loss: 0.01860262 ---------------- Val_Acc: Val_Loss: 0.01865640
# epoch: 15 -> Loss: 0.01855675 ---------------- Val_Acc: Val_Loss: 0.01867495
# epoch: 16 -> Loss: 0.01854603 ---------------- Val_Acc: Val_Loss: 0.01866439
# epoch: 17 -> Loss: 0.01854208 ---------------- Val_Acc: Val_Loss: 0.01851783
# epoch: 18 -> Loss: 0.01832372 ---------------- Val_Acc: Val_Loss: 0.01802828
# epoch: 19 -> Loss: 0.01790456 ---------------- Val_Acc: Val_Loss: 0.01793751
# epoch: 20 -> Loss: 0.01778403 ---------------- Val_Acc: Val_Loss: 0.01786094
# epoch: 21 -> Loss: 0.01773813 ---------------- Val_Acc: Val_Loss: 0.01777719
# epoch: 22 -> Loss: 0.01772568 ---------------- Val_Acc: Val_Loss: 0.01783252
# epoch: 23 -> Loss: 0.01768032 ---------------- Val_Acc: Val_Loss: 0.01770557
# epoch: 24 -> Loss: 0.01761555 ---------------- Val_Acc: Val_Loss: 0.01769172
# epoch: 25 -> Loss: 0.01744477 ---------------- Val_Acc: Val_Loss: 0.01785033
# epoch: 26 -> Loss: 0.01725657 ---------------- Val_Acc: Val_Loss: 0.01739501
# epoch: 27 -> Loss: 0.01713561 ---------------- Val_Acc: Val_Loss: 0.01714658
# epoch: 28 -> Loss: 0.01703178 ---------------- Val_Acc: Val_Loss: 0.01711412
# epoch: 29 -> Loss: 0.01699854 ---------------- Val_Acc: Val_Loss: 0.01713540
# epoch: 30 -> Loss: 0.01697594 ---------------- Val_Acc: Val_Loss: 0.01705551
# epoch: 31 -> Loss: 0.01696277 ---------------- Val_Acc: Val_Loss: 0.01700020
# epoch: 32 -> Loss: 0.01693276 ---------------- Val_Acc: Val_Loss: 0.01702208
# epoch: 33 -> Loss: 0.01688047 ---------------- Val_Acc: Val_Loss: 0.01700798
# epoch: 34 -> Loss: 0.01687073 ---------------- Val_Acc: Val_Loss: 0.01697054
# epoch: 35 -> Loss: 0.01686600 ---------------- Val_Acc: Val_Loss: 0.01698187
# epoch: 36 -> Loss: 0.01686237 ---------------- Val_Acc: Val_Loss: 0.01695801
# epoch: 37 -> Loss: 0.01680660 ---------------- Val_Acc: Val_Loss: 0.01692713
# epoch: 38 -> Loss: 0.01679627 ---------------- Val_Acc: Val_Loss: 0.01693199
# epoch: 39 -> Loss: 0.01679391 ---------------- Val_Acc: Val_Loss: 0.01692260
# epoch: 40 -> Loss: 0.01676708 ---------------- Val_Acc: Val_Loss: 0.01692749
# Training time in second: 1018.0977803000133

# %%
plot_learning_acc_and_loss(loss_train, loss_val)

# %%
test(DEEP_non_AE)
# Out:
# Test Loss: 0.01693725

# %%
encoded_imgs, decoded_imgs = apply_on_test(model=DEEP_non_AE, device=device)

plot_img(10, [x_test, decoded_imgs], title="Original (top) vs reconstruction (bottom)")

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# Write a short report of the results you obtained trying different hyperparameters configurations.

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# **ANSWER**:
#
# Results of the experiments with different configurations:
#
#
# First experiment:
#
# ENC_LAYERS = [512,  256, 128]
# DEC_LAYERS = [256, 512]
# ACT_FUN = 'sigmoid'
#
# test loss: 0.027
#
# Second experiment:
#
# ENC_LAYERS = [1024, 512,  256]
# DEC_LAYERS = [512,1024]
# ACT_FUN = 'sigmoid'
#
# test loss: 0.0385
#
#
# Third experiment:
#
# ENC_LAYERS = [512, 256, 128]
# DEC_LAYERS = [256, 512]
# ACT_FUN = 'relu'
# lr = 0.005
# test_loss: 0.019
#
# Forth experiment:
#
# IN_DIM = x_train.shape[-1]
# ENC_LAYERS = [512, 256, 128]
# DEC_LAYERS = [256, 512]
# ACT_FUN = 'relu'
# lr = 0.001
# epochs = 40
#
# test_loss: 0.016
#
# On the basis of these findings, it may be concluded that ReLU activation typically outperforms sigmoid activation. The test loss can also be affected by changing the learning rate and the number of epochs. In both studies using ReLU activation, the architecture with [512, 256, 128] for the encoder and [256, 512] for the decoder appears to be successful in reducing test loss.

# %% [markdown]
# `%ENDTEXT`

# %% [markdown]
# # [TO COMPLETE] Shallow Denoising Autoencoder

# %% [markdown]
# **[TO COMPLETE]** Let's now use a shallow autoencoder to denoise the input data. We have defined a Dataloader able to return a noisy version of the input data. You can activate this capability by passing the parameter `denoising=True` to the `train` function.
#
# Run some experiments with different hyperparameters values. You can also re-create the dataloaders at the beginning of the notebook and test what happens if you increase the noise level above $0.1$. Write a short report of your findings below.

# %%
noise_factor = 0.2 # adjust the noise level here.

dataloader_train_AE = DataLoader(CustomDataset(train_data, noise_factor, device), batch_size = batch_size)
dataloader_val_AE = DataLoader(CustomDataset(val_data, noise_factor, device), batch_size = batch_size)
dataloader_test_AE = DataLoader(CustomDataset(test_data, noise_factor, device), batch_size = batch_size)

# %%
plot_img(10, [x_test, x_test_noisy])

# %% [markdown]
# `%STARTCODE`

# %%
# [TO COMPLETE]
# define model and training hyperparameters

IN_DIM = x_train.shape[-1]
ENC_LAYERS = [256] 
DEC_LAYERS = [] 
ACT_FUN = 'sigmoid'
lr = 0.005
epochs = 30
# END

SHALLOW_denoising_AE = Auto_Encoder(IN_DIM, ENC_LAYERS, DEC_LAYERS, ACT_FUN).to(device)
summary(SHALLOW_denoising_AE, input_size=(batch_size, IN_DIM))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Auto_Encoder                             [512, 1024]               --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [512, 256]                262,400
# ├─ModuleList: 1-2                        --                        --
# │    └─Linear: 2-2                       [512, 1024]               263,168
# ==========================================================================================
# Total params: 525,568
# Trainable params: 525,568
# Non-trainable params: 0
# Total mult-adds (M): 269.09
# ==========================================================================================
# Input size (MB): 2.10
# Forward/backward pass size (MB): 5.24
# Params size (MB): 2.10
# Estimated Total Size (MB): 9.44
# ==========================================================================================

# %%
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(SHALLOW_denoising_AE.parameters(), lr=lr)

# %%
start = timer()

# [TO COMPLETE]
# call the training function on noisy data
loss_train, loss_val = train(SHALLOW_denoising_AE, optimizer, dataloader_train_AE,
                             dataloader_val_AE, epochs, denoising= True)

end = timer()
print(f"Training time in second: {round(end - start)}")
# Out:
# epoch: 1 -> Loss: 0.04398912 ---------------- Val_Acc: Val_Loss: 0.02993280
# epoch: 2 -> Loss: 0.02531138 ---------------- Val_Acc: Val_Loss: 0.02119817
# epoch: 3 -> Loss: 0.02084633 ---------------- Val_Acc: Val_Loss: 0.01893772
# epoch: 4 -> Loss: 0.01744226 ---------------- Val_Acc: Val_Loss: 0.01753142
# epoch: 5 -> Loss: 0.01710215 ---------------- Val_Acc: Val_Loss: 0.01597262
# epoch: 6 -> Loss: 0.01503194 ---------------- Val_Acc: Val_Loss: 0.01451263
# epoch: 7 -> Loss: 0.01444772 ---------------- Val_Acc: Val_Loss: 0.01447723
# epoch: 8 -> Loss: 0.01402800 ---------------- Val_Acc: Val_Loss: 0.01427976
# epoch: 9 -> Loss: 0.01330425 ---------------- Val_Acc: Val_Loss: 0.01284898
# epoch: 10 -> Loss: 0.01287266 ---------------- Val_Acc: Val_Loss: 0.01237201
# epoch: 11 -> Loss: 0.01258504 ---------------- Val_Acc: Val_Loss: 0.01225271
# epoch: 12 -> Loss: 0.01242372 ---------------- Val_Acc: Val_Loss: 0.01191522
# epoch: 13 -> Loss: 0.01212685 ---------------- Val_Acc: Val_Loss: 0.01197863
# epoch: 14 -> Loss: 0.01185509 ---------------- Val_Acc: Val_Loss: 0.01147988
# epoch: 15 -> Loss: 0.01165675 ---------------- Val_Acc: Val_Loss: 0.01136362
# epoch: 16 -> Loss: 0.01145049 ---------------- Val_Acc: Val_Loss: 0.01134842
# epoch: 17 -> Loss: 0.01122667 ---------------- Val_Acc: Val_Loss: 0.01091068
# epoch: 18 -> Loss: 0.01129332 ---------------- Val_Acc: Val_Loss: 0.01078320
# epoch: 19 -> Loss: 0.01091729 ---------------- Val_Acc: Val_Loss: 0.01069266
# epoch: 20 -> Loss: 0.01093129 ---------------- Val_Acc: Val_Loss: 0.01071348
# epoch: 21 -> Loss: 0.01097287 ---------------- Val_Acc: Val_Loss: 0.01218625
# epoch: 22 -> Loss: 0.01070077 ---------------- Val_Acc: Val_Loss: 0.01035575
# epoch: 23 -> Loss: 0.01060723 ---------------- Val_Acc: Val_Loss: 0.01096195
# epoch: 24 -> Loss: 0.01056792 ---------------- Val_Acc: Val_Loss: 0.01111908
# epoch: 25 -> Loss: 0.01037006 ---------------- Val_Acc: Val_Loss: 0.01017019
# epoch: 26 -> Loss: 0.01045577 ---------------- Val_Acc: Val_Loss: 0.01041399
# epoch: 27 -> Loss: 0.01023445 ---------------- Val_Acc: Val_Loss: 0.01014842
# epoch: 28 -> Loss: 0.01021609 ---------------- Val_Acc: Val_Loss: 0.00995174
# epoch: 29 -> Loss: 0.01011973 ---------------- Val_Acc: Val_Loss: 0.01048176
# epoch: 30 -> Loss: 0.01014377 ---------------- Val_Acc: Val_Loss: 0.01023690
# Training time in second: 1736

# %%
plot_learning_acc_and_loss(loss_train, loss_val)

# %%
test(SHALLOW_denoising_AE, denoising=True)
# Out:
# Test Loss: 0.00872433

# %%
encoded_imgs, decoded_imgs = apply_on_test(model=SHALLOW_denoising_AE, device=device, denoising=True)

plot_img(10, [x_test_noisy, x_test, decoded_imgs], title="Noisy, Original vs Reconstruction")

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# How strong is the impact of the noise factor on the model's denoising capability? What hyperparameter configuration worked for the noise levels you have tried?

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# **ANSWER**:
#
# Results of the experiments with different configurations:
#
# First Experiment:
#
# ENC_LAYERS = [256]
# DEC_LAYERS = []
# ACT_FUN = 'sigmoid'
# lr = 0.005
# epochs = 30
# noise_factor = 0.15
# test loss = 0.008
# Good image reconstruction
#
# Second Experiment:
#
# ENC_LAYERS = [256]
# DEC_LAYERS = []
# ACT_FUN = 'relu'
# lr = 0.005
# epochs = 30
# noise_factor = 0.2
# test loss = 0.03
# Bad image reconstruction
#
# Third Experiment:
#
# ENC_LAYERS = [256]
# DEC_LAYERS = []
# ACT_FUN = 'sigmoid'
# lr = 0.005
# epochs = 30
# noise_factor = 0.2
# test_loss = 0.0087
# Acceptable image reconstruction but worst than SVD
#
#
# These trials have shown that the noise factor significantly affects the model's capacity to denoise. In comparison to Experiment 2, which had a greater noise factor of 0.2, Experiment 1's denoising performance was better with a lower noise value of 0.15. A test loss of 0.03 was obtained in Experiment 2 using the Denoising Autoencoder with a noise factor of 0.2 and the relu activation function, which is a somewhat lower denoising efficiency than in the preceding trials. The model produced a lower test loss of 0.0087 in Experiment 3 using the sigmoid activation function and a noise factor of 0.2, showing greater denoising performance. A lower noise factor tends to improve the denoising capability of the model.

# %% [markdown]
# `%ENDTEXT`
